# %% [markdown]
# # 1. 트리 ( Tree )

# %% [markdown]
# ## 트리는 가계도와 같은 계층적인 구조를 표현할 때 사용
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ### 트리 관련 용어
# ### - 루트 노드 : 부모가 없는 최상위 노드
# ### - 자식 노드 : 노드 하위에 연결된 노드
# ### - 단말 노드 : 자식이 없는 노드
# ### - 크기 : 트리에 포함된 모든 노드의 개수
# ### - 깊이 : 루트 노드부터의 거리
# ### - 높이 : 깊이 중 최댓값, 트리의 최대 레벨
# ### - 차수 : 각 노드의 (자식 방향) 간선 개수, 자식 노드 수
# ### - 이파리 노드 : 자식이 없는 노드
# ### - 형제 노드 : 동일한 부모를 가지는 노드
# ### - 조상 노드 : 루트 노드까지의 경로상에 있는 모든 노드들의 집합
# ### - 후손 노드 : 노드 아래로 매달린 모든 노드들의 집합
# ### - 서브 트리 : 노드 자신과 후손노드로 구성된 트리
# ### - 레벨 : 깊이
# ### - 키 : 탐색에 사용되는 노드에 저장된 정보
#
# #### 기본적으로 트리의 크기가 N일 때, 전체 간선의 개수는 N - 1 개

# %% [markdown]
# # 2. 이진 탐색 트리

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ### 이진 탐색이 동작할 수 있도록 고안된 효율적인 탐색이 가능
# ### 이진 탐색 트리의 특징 : 왼쪽 자식 노드 < 부모 노드 < 오른쪽 자식노드
# #### 부모 노드보다 왼쪽 자식 노드가 작습니다.
# #### 부모 노드보다 오른쪽 자식 노드가 큽니다.

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
class Node :
    def __init__(self, data, left_node, right_node) :
        self.data = data
        self.left_node = left_node
        self.right_node = right_node
        
# 전위 순회
def pre_order(node) :
    print(node.data, end = ' ')
    if node.left_node != None :
        pre_order(tree[node.left_node])
    if node.right_node != None :
        pre_order(tree[node.right_node])
        
# 중위 순회
def in_order(node) :
    if node.left_node != None :
        in_order(tree[node.left_node])
    print(node.data, end = ' ')
    if node.right_node != None :
        in_order(tree[node.right_node])
        
# 후위 순회
def post_order(node) :
    if node.left_node != None :
        post_order(tree[node.left_node])
    if node.right_node != None :
        post_order(tree[node.right_node])
    print(node.data, end = ' ')
    
n = int(input())
tree = {}

for i in range(n) :
    data, left_node, right_node = input().split()
    if left_node == "None" :
        left_node = None
    if right_node == "None" :
        right_node = None
    tree[data] = Node(data, left_node, right_node)
    
pre_order(tree['A'])
print()
in_order(tree['A'])
print()
post_order(tree['A'])
# Out:
# 7
# A B C
# B D E
# C F G
# D None None
# E None None
# F None None
# G None None
# A B D E C F G
# D B E A F C G
# D E B F G C A
